# %% [markdown]
# ## Association Rules Market Basket Analysis

# %% [markdown]
# ## Import Package

# %%
# library
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ## Load Data
#
# ini tempat loading data

# %%
# load data to dataframe
df = pd.read_excel('http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %% [markdown]
# # Data Understanding

# %%
# data profile
print('Data dimension (total row, total column) : {dim}' .format(dim=df.shape))
print('Count of unique invoice number : {count}' .format(count=df.InvoiceNo.nunique()))
print('Number of customer ID : {count}' .format(count=df.CustomerID.nunique()))
# Out:
# Data dimension (total row, total column) : (541909, 8)
# Count of unique invoice number : 25900
# Number of customer ID : 4372

# %%
#number of 
df.isnull().sum(axis = 0)
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# # Data Preparation

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['CustomerID'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')] # C is credit

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Greece', 'Singapore', 'Lebanon',
#        'United Arab Emirates', 'Israel', 'Saudi Arabia', 'Czech Republic',
#        'Canada', 'Unspecified', 'Brazil', 'USA', 'European Community',
#        'Bahrain', 'Malta', 'RSA'], dtype=object)

# %%
basket = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                          0.0  ...                              0.0
# 536852                          0.0  ...                              0.0
# 536974                          0.0  ...                              0.0
# 537065                          0.0  ...                              0.0
# 537463                          0.0  ...                              0.0
# ...                             ...  ...                              ...
# 580986                          0.0  ...                              0.0
# 581001                          0.0  ...                              0.0
# 581171                          0.0  ...                              0.0
# 581279                          0.0  ...                              0.0
# 581587                          0.0  ...                              0.0
#
# [389 rows x 1543 columns]

# %% [markdown]
# Quite a lot of zeros in the data but we also need to make sure any positive values are converted to a 1 and anything less the 0 is set to 0. so, let’s apply one hot encoding of the data and remove the postage column

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)

# we are not going to explore postage. 
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_sets
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                            0  ...                                0
# 536852                            0  ...                                0
# 536974                            0  ...                                0
# 537065                            0  ...                                0
# 537463                            0  ...                                0
# ...                             ...  ...                              ...
# 580986                            0  ...                                0
# 581001                            0  ...                                0
# 581171                            0  ...                                0
# 581279                            0  ...                                0
# 581587                            0  ...                                0
#
# [389 rows x 1542 columns]

# %% [markdown]
# # Modeling

# %%
# set minimum support
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)

# %%
# list of rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                     antecedents  ... conviction
# 0   (ALARM CLOCK BAKELIKE PINK)  ...   3.281140
# 1  (ALARM CLOCK BAKELIKE GREEN)  ...   3.788061
# 2  (ALARM CLOCK BAKELIKE GREEN)  ...   4.912229
# 3    (ALARM CLOCK BAKELIKE RED)  ...   5.564267
# 4   (ALARM CLOCK BAKELIKE PINK)  ...   3.290488
#
# [5 rows x 9 columns]

# %%
# total number of association rule
print('"number of association" {}'. format(rules.shape[0]))
# Out:
# "number of association" 26

# %%
# plot confidence results
rules.hist('confidence', grid =False, bins =30)
plt.title("Confidence")
# Out:
# Text(0.5, 1.0, 'Confidence')

# %%
# plot lift results
rules.hist('lift', grid =False, bins =30)
plt.title("Lift")
# Out:
# Text(0.5, 1.0, 'Lift')

# %% [markdown]
# ## Results

# %%
# set minumum lift and confidence
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8) ]
# Out:
#                                           antecedents  ... conviction
# 2                        (ALARM CLOCK BAKELIKE GREEN)  ...   4.912229
# 3                          (ALARM CLOCK BAKELIKE RED)  ...   5.564267
# 18                      (SET/6 RED SPOTTY PAPER CUPS)  ...   7.843188
# 19                    (SET/6 RED SPOTTY PAPER PLATES)  ...  21.529563
# 20  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...  ...   4.620394
# 21  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...  ...  34.858612
# 22  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...  ...  34.447301
#
# [7 rows x 9 columns]

# %% [markdown]
# ## Check popularity of items

# %%
basket['ALARM CLOCK BAKELIKE GREEN'].sum()
# Out:
# 340.0

# %%
basket['ALARM CLOCK BAKELIKE RED'].sum()
# Out:
# 316.0
